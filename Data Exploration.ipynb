# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('jobs/fake_job_postings.csv')

# %%
df.head()
# Out:
#    job_id                                      title            location  \
# 0       1                           Marketing Intern    US, NY, New York
# 1       2  Customer Service - Cloud Video Production      NZ, , Auckland
# 2       3    Commissioning Machinery Assistant (CMA)       US, IA, Wever
# 3       4          Account Executive - Washington DC  US, DC, Washington
# 4       5                        Bill Review Manager  US, FL, Fort Worth
#
#   department salary_range                                    company_profile  \
# 0  Marketing          NaN  We're Food52, and we've created a groundbreaki...
# 1    Success          NaN  90 Seconds, the worlds Cloud Video Production ...
# 2        NaN          NaN  Valor Services provides Workforce Solutions th...
# 3      Sales          NaN  Our passion for improving quality of life thro...
# 4        NaN          NaN  SpotSource Solutions LLC is a Global Human Cap...
#
#                                          description  \
# ...

# %%
df['salary_range'].fillna(0,inplace=True)

# %%
df.head()
# Out:
#    job_id                                      title            location  \
# 0       1                           Marketing Intern    US, NY, New York
# 1       2  Customer Service - Cloud Video Production      NZ, , Auckland
# 2       3    Commissioning Machinery Assistant (CMA)       US, IA, Wever
# 3       4          Account Executive - Washington DC  US, DC, Washington
# 4       5                        Bill Review Manager  US, FL, Fort Worth
#
#   department salary_range                                    company_profile  \
# 0  Marketing            0  We're Food52, and we've created a groundbreaki...
# 1    Success            0  90 Seconds, the worlds Cloud Video Production ...
# 2        NaN            0  Valor Services provides Workforce Solutions th...
# 3      Sales            0  Our passion for improving quality of life thro...
# 4        NaN            0  SpotSource Solutions LLC is a Global Human Cap...
#
#                                          description  \
# ...

# %%
def salary(value):
    if value != 0:
        return 1
    else:
        return 0
df['salary_range'] = df['salary_range'].apply(salary)

# %%
df_fake = df[df['fraudulent'] == 1]
df_real = df[df['fraudulent'] == 0]

# %%
df_fake.salary_range.value_counts() #2.83
# Out:
# 0    643
# 1    223
# Name: salary_range, dtype: int64

# %%
df_real.salary_range.value_counts() #5.43
# Out:
# 0    14369
# 1     2645
# Name: salary_range, dtype: int64

# %%
df.fillna('',inplace=True)

# %%
fake_dept = dict(df_fake.department.value_counts())
real_dept = dict(df_real.department.value_counts())

# %%
fake_dept
# Out:
# {'Engineering': 46,
#  'Clerical': 27,
#  'Oil & Energy': 24,
#  'Information Technology': 15,
#  'Customer Service': 14,
#  'Administrative': 14,
#  'Sales': 12,
#  'Information Technology ': 12,
#  'Engineering ': 9,
#  'admin': 7,
#  'Accounting/Payroll': 6,
#  'sales': 5,
#  'ENGINEERING': 5,
#  'CALL CENTER': 5,
#  'Sales and Research': 5,
#  'Maintenance': 4,
#  'Account': 4,
#  'Oil & Energy ': 4,
#  'customer service': 4,
#  'Admin/Clerical': 3,
#  'HR': 3,
#  'CSR CENTER': 3,
#  'CSR': 3,
#  'Data Entry': 3,
#  'Controls Engineer': 3,
#  'Human Resources': 3,
#  'Client Services': 2,
#  'Administration support': 2,
#  'Biotech ': 2,
#  'Account/finance': 2,
#  'Product Development': 2,
#  'biotech': 2,
#  'HSE (Health Safety Environmental)': 2,
#  'Power Plant & Energy': 2,
#  'Financial Dept': 2,
#  'Work at home': 2,
#  'medical': 2,
#  'Accounting': 2,
#  'Accounting/Finance': 2,
#  'Marketing': 2,
#  'CALLCENTER': 2,
#  'Technician': 1,
#  'DRIVER': 1,
#  'MAINT': 1,
# ...

# %%
real_dept
# Out:
# {'Sales': 539,
#  'Engineering': 441,
#  'Marketing': 399,
#  'Operations': 270,
#  'IT': 224,
#  'Development': 146,
#  'Product': 112,
#  'Design': 76,
#  'Technology': 75,
#  'Information Technology': 71,
#  'Finance': 69,
#  'Customer Service': 59,
#  'tech': 55,
#  'R&D': 54,
#  'HR': 53,
#  'Creative': 48,
#  'Retail': 45,
#  'Client Services': 43,
#  'Product Development': 34,
#  'Production': 32,
#  'Business Development': 32,
#  'Oil and Gas': 32,
#  'CSD Relay': 31,
#  'Technical': 29,
#  'Tech': 29,
#  'Administration': 27,
#  'Accounting': 27,
#  'Human Resources': 26,
#  'Editorial': 26,
#  'Maintenance': 26,
#  'Legal': 23,
#  'IT Services': 23,
#  'Department': 23,
#  'Performance Marketing': 22,
#  'Content': 20,
#  'Squiz ': 20,
#  'Admin': 19,
#  'Project Management': 19,
#  'QA': 18,
#  'Creative Services': 18,
#  'Commercial': 18,
#  'Didactics': 17,
#  'Support': 17,
#  'International Growth': 17,
#  'Administrative': 16,
#  'Management': 16,
#  'All': 16,
# ...
